# %% [markdown]
# # Swin Transfomer
#
# BCE loss implemented correctly
#
# average auc calculated manually using loss for each diagnosis

# %%
# Mount into drive
from google.colab import drive
drive.mount("/content/drive")
# !cp '/content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/CheXpert-v1.0-small.zip' /content/
# !mkdir CheXpert
# !unzip '/content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/CheXpert-v1.0-small.zip' -d /content/CheXpert
import sys
sys.path.append('/content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/tyler')
sys.path.append('/content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation')
sys.path.append('/content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/models')

# %%
# imports
# !pip install transformers
import numpy as np
import pandas as pd

# %load_ext autoreload
# %autoreload 2

import torch
print(torch.cuda.is_available())

from transformers import AutoFeatureExtractor, SwinForImageClassification, SwinConfig
from transformers import TrainingArguments, Trainer
from torchvision.transforms import RandomHorizontalFlip, RandomResizedCrop
from torchvision.transforms.functional import InterpolationMode

from sklearn.model_selection import train_test_split

# %%
# !pip install libauc
from dataloader import *
from utils import *
from trainer import *

# %%
# CONSTANTS
FEATURE_EXTRACTOR_NAME = 'microsoft/swin-base-patch4-window7-224'
VIT_MODEL_NAME = 'microsoft/swin-base-patch4-window7-224'
TRAIN_SPLIT = 0.8
BATCH_SIZE = 48
LEARNING_RATE = 1.5e-3
LR_SCHEDULER_TYPE = "cosine"
WEIGHT_DECAY = 0.05
WARMUP_RATIO = 0.05
LOGGING_STRATEGY = "steps"
LOGGING_STEPS = 10
FP16 = True
EPOCHS = 10
EVALUATION_STRATEGY = "epoch"
EVAL_STEPS = 200
OUTPUT_DIR = '/content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output'
REMOVE_UNUSED_COLUMNS = False
GRAD_ACCUM_STEPS = 5
DATALOADER_NUM_WORKERS = 4

# %%
feature_extractor = AutoFeatureExtractor.from_pretrained(FEATURE_EXTRACTOR_NAME, image_mean=[0.485, 0.456, 0.406], image_std=[0.229, 0.224, 0.225])
# Out:
# Downloading:   0%|          | 0.00/255 [00:00<?, ?B/s]

# %%
# set up our transforms
transforms = [
    RandomResizedCrop(feature_extractor.size, scale=(0.2, 1.0), interpolation=InterpolationMode.BICUBIC),
    RandomHorizontalFlip(),
]

# %%
np.random.seed(42)
train_df = pd.read_csv("/content/CheXpert/CheXpert-v1.0-small/train.csv")
train_df, eval_df = train_test_split(train_df, train_size=TRAIN_SPLIT)

train_dataset = ChexpertViTDataset("/content/CheXpert", train_df, feature_extractor, transforms=transforms, classes=COMPETITION_TASKS,
    uncertainty_method="smooth", smoothing_lower_bound=0.55, smoothing_upper_bound=0.85, use_frontal = False)
eval_dataset = ChexpertViTDataset("/content/CheXpert", eval_df, feature_extractor, classes=COMPETITION_TASKS,
    uncertainty_method="smooth", smoothing_lower_bound=0.55, smoothing_upper_bound=0.85, use_frontal = False)

# %%
model = SwinForImageClassification.from_pretrained(
    VIT_MODEL_NAME,
    num_labels=len(train_dataset.labels),
    ignore_mismatched_sizes = True
).to("cuda")
# Out:
# Downloading:   0%|          | 0.00/70.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/335M [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Some weights of SwinForImageClassification were not initialized from the model checkpoint at microsoft/swin-base-patch4-window7-224 and are newly initialized because the shapes did not match:
# - classifier.weight: found shape torch.Size([1000, 1024]) in the checkpoint and torch.Size([5, 1024]) in the model instantiated
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([5]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# set up training arguments
training_args = TrainingArguments(
    output_dir=OUTPUT_DIR,
    per_device_train_batch_size=BATCH_SIZE,
    per_device_eval_batch_size=BATCH_SIZE,
    evaluation_strategy=EVALUATION_STRATEGY,
    num_train_epochs=EPOCHS,
    fp16=FP16,
    eval_steps = EVAL_STEPS,
    learning_rate=LEARNING_RATE,
    remove_unused_columns=REMOVE_UNUSED_COLUMNS,
    report_to="tensorboard",
    gradient_accumulation_steps=GRAD_ACCUM_STEPS,
    lr_scheduler_type=LR_SCHEDULER_TYPE,
    weight_decay=WEIGHT_DECAY,
    warmup_ratio=WARMUP_RATIO,
    logging_strategy=LOGGING_STRATEGY,
    logging_steps=LOGGING_STEPS,
    dataloader_num_workers=DATALOADER_NUM_WORKERS
)

# %%
trainer = MultiLabelTrainer(
    model=model,
    args=training_args,
    compute_metrics=compute_metrics,
    data_collator=collate_fn,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
)
# Out:
# Using amp half precision backend

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 178731
#   Num Epochs = 10
#   Instantaneous batch size per device = 48
#   Total train batch size (w. parallel, distributed & accumulation) = 240
#   Gradient Accumulation steps = 5
#   Total optimization steps = 7440
#     <div>
#
#       <progress value='7220' max='7440' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7220/7440 10:56:43 < 20:01, 0.18 it/s, Epoch 9.70/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Auc Atelectasis</th>
#       <th>Auc Cardiomegaly</th>
#       <th>Auc Consolidation</th>
#       <th>Auc Edema</th>
#       <th>Auc Pleural effusion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.466500</td>
#       <td>0.461647</td>
#       <td>0.314773</td>
#       <td>0.349568</td>
#       <td>0.675752</td>
#       <td>0.775204</td>
#       <td>0.649969</td>
#       <td>0.796120</td>
#       <td>0.829578</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.467000</td>
#       <td>0.442931</td>
#       <td>0.344561</td>
#       <td>0.462309</td>
#       <td>0.679684</td>
#       <td>0.799272</td>
#       <td>0.659474</td>
#       <td>0.815262</td>
#       <td>0.844354</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.452900</td>
#       <td>0.447847</td>
#       <td>0.338003</td>
#       <td>0.413827</td>
#       <td>0.680502</td>
#       <td>0.791029</td>
#       <td>0.661756</td>
#       <td>0.820727</td>
#       <td>0.844840</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.456400</td>
#       <td>0.439406</td>
#       <td>0.347425</td>
#       <td>0.468146</td>
#       <td>0.687642</td>
#       <td>0.815315</td>
#       <td>0.668635</td>
#       <td>0.819412</td>
#       <td>0.850743</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.447000</td>
#       <td>0.431632</td>
#       <td>0.349954</td>
#       <td>0.447965</td>
#       <td>0.690407</td>
#       <td>0.818786</td>
#       <td>0.673748</td>
#       <td>0.831060</td>
#       <td>0.856612</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.441200</td>
#       <td>0.429835</td>
#       <td>0.355303</td>
#       <td>0.506524</td>
#       <td>0.697400</td>
#       <td>0.822069</td>
#       <td>0.679805</td>
#       <td>0.837027</td>
#       <td>0.862678</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.447800</td>
#       <td>0.423867</td>
#       <td>0.363785</td>
#       <td>0.503155</td>
#       <td>0.699785</td>
#       <td>0.831796</td>
#       <td>0.681194</td>
#       <td>0.841611</td>
#       <td>0.866402</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.436200</td>
#       <td>0.418059</td>
#       <td>0.366985</td>
#       <td>0.506299</td>
#       <td>0.706208</td>
#       <td>0.837253</td>
#       <td>0.689498</td>
#       <td>0.844203</td>
#       <td>0.871248</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.414300</td>
#       <td>0.415012</td>
#       <td>0.373162</td>
#       <td>0.516476</td>
#       <td>0.709916</td>
#       <td>0.839145</td>
#       <td>0.690368</td>
#       <td>0.849718</td>
#       <td>0.873577</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-500
# Configuration saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-500/config.json
# Model weights saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 44683
#   Batch size = 48
# Saving model checkpoint to /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-1000
# Configuration saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-1000/config.json
# Model weights saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-1000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 44683
#   Batch size = 48
# Saving model checkpoint to /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-1500
# Configuration saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-1500/config.json
# Model weights saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-1500/pytorch_model.bin
# Saving model checkpoint to /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-2000
# Configuration saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-2000/config.json
# Model weights saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-2000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 44683
#   Batch size = 48
# Saving model checkpoint to /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-2500
# Configuration saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-2500/config.json
# Model weights saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-2500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 44683
#   Batch size = 48
# Saving model checkpoint to /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-3000
# Configuration saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-3000/config.json
# Model weights saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-3000/pytorch_model.bin
# Saving model checkpoint to /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-3500
# Configuration saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-3500/config.json
# Model weights saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-3500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 44683
#   Batch size = 48
# Saving model checkpoint to /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-4000
# Configuration saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-4000/config.json
# Model weights saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-4000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 44683
#   Batch size = 48
# Saving model checkpoint to /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-4500
# Configuration saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-4500/config.json
# Model weights saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-4500/pytorch_model.bin
# Saving model checkpoint to /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-5000
# Configuration saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-5000/config.json
# Model weights saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-5000/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 44683
#   Batch size = 48
# Saving model checkpoint to /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-5500
# Configuration saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-5500/config.json
# Model weights saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-5500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 44683
#   Batch size = 48
# Saving model checkpoint to /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-6000
# Configuration saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-6000/config.json
# Model weights saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-6000/pytorch_model.bin
# Saving model checkpoint to /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-6500
# Configuration saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-6500/config.json
# Model weights saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-6500/pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 44683
#   Batch size = 48
# Saving model checkpoint to /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-7000
# Configuration saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-7000/config.json
# Model weights saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/checkpoint-7000/pytorch_model.bin
#     <div>
#
#       <progress value='7440' max='7440' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7440/7440 11:20:41, Epoch 9/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Auc Atelectasis</th>
#       <th>Auc Cardiomegaly</th>
#       <th>Auc Consolidation</th>
#       <th>Auc Edema</th>
#       <th>Auc Pleural effusion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.466500</td>
#       <td>0.461647</td>
#       <td>0.314773</td>
#       <td>0.349568</td>
#       <td>0.675752</td>
#       <td>0.775204</td>
#       <td>0.649969</td>
#       <td>0.796120</td>
#       <td>0.829578</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.467000</td>
#       <td>0.442931</td>
#       <td>0.344561</td>
#       <td>0.462309</td>
#       <td>0.679684</td>
#       <td>0.799272</td>
#       <td>0.659474</td>
#       <td>0.815262</td>
#       <td>0.844354</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.452900</td>
#       <td>0.447847</td>
#       <td>0.338003</td>
#       <td>0.413827</td>
#       <td>0.680502</td>
#       <td>0.791029</td>
#       <td>0.661756</td>
#       <td>0.820727</td>
#       <td>0.844840</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.456400</td>
#       <td>0.439406</td>
#       <td>0.347425</td>
#       <td>0.468146</td>
#       <td>0.687642</td>
#       <td>0.815315</td>
#       <td>0.668635</td>
#       <td>0.819412</td>
#       <td>0.850743</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.447000</td>
#       <td>0.431632</td>
#       <td>0.349954</td>
#       <td>0.447965</td>
#       <td>0.690407</td>
#       <td>0.818786</td>
#       <td>0.673748</td>
#       <td>0.831060</td>
#       <td>0.856612</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.441200</td>
#       <td>0.429835</td>
#       <td>0.355303</td>
#       <td>0.506524</td>
#       <td>0.697400</td>
#       <td>0.822069</td>
#       <td>0.679805</td>
#       <td>0.837027</td>
#       <td>0.862678</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.447800</td>
#       <td>0.423867</td>
#       <td>0.363785</td>
#       <td>0.503155</td>
#       <td>0.699785</td>
#       <td>0.831796</td>
#       <td>0.681194</td>
#       <td>0.841611</td>
#       <td>0.866402</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.436200</td>
#       <td>0.418059</td>
#       <td>0.366985</td>
#       <td>0.506299</td>
#       <td>0.706208</td>
#       <td>0.837253</td>
#       <td>0.689498</td>
#       <td>0.844203</td>
#       <td>0.871248</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.414300</td>
#       <td>0.415012</td>
#       <td>0.373162</td>
#       <td>0.516476</td>
#       <td>0.709916</td>
#       <td>0.839145</td>
#       <td>0.690368</td>
#       <td>0.849718</td>
#       <td>0.873577</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.427800</td>
#       <td>0.414367</td>
#       <td>0.373431</td>
#       <td>0.522517</td>
#       <td>0.710263</td>
#       <td>0.840343</td>
#       <td>0.691253</td>
#       <td>0.849733</td>
#       <td>0.874067</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 44683
#   Batch size = 48
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=7440, training_loss=0.4465117412228738, metrics={'train_runtime': 40848.546, 'train_samples_per_second': 43.755, 'train_steps_per_second': 0.182, 'total_flos': 1.4001936125630128e+20, 'train_loss': 0.4465117412228738, 'epoch': 10.0})

# %%
trainer.evaluate()
# Out:
# ***** Running Evaluation *****
#   Num examples = 44683
#   Batch size = 48
#     <div>
#
#       <progress value='931' max='931' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [931/931 05:22]
#     </div>
# {'epoch': 10.0,
#  'eval_AUC_Atelectasis': 0.7102629943604462,
#  'eval_AUC_Cardiomegaly': 0.840342841555816,
#  'eval_AUC_Consolidation': 0.6912530769091636,
#  'eval_AUC_Edema': 0.8497326658106499,
#  'eval_AUC_Pleural Effusion': 0.874066771768063,
#  'eval_accuracy': 0.373430611194414,
#  'eval_f1': 0.5225168283664634,
#  'eval_loss': 0.41436660289764404,
#  'eval_runtime': 323.2158,
#  'eval_samples_per_second': 138.245,
#  'eval_steps_per_second': 2.88}

# %%
trainer.save_state()

# %%
trainer.save_model()
# Out:
# Saving model checkpoint to /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output
# Configuration saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/config.json
# Model weights saved in /content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/swin-chexpert-fine-tuned-output/pytorch_model.bin

# %%
validation_df = pd.read_csv("/content/CheXpert/CheXpert-v1.0-small/valid.csv")
valid_dataset = ChexpertViTDataset("/content/CheXpert", validation_df, feature_extractor, classes=COMPETITION_TASKS,
    uncertainty_method="smooth", smoothing_lower_bound=0.55, smoothing_upper_bound=0.85, use_frontal = False)

# %%
trainer.evaluate(eval_dataset=valid_dataset)
# Out:
# ***** Running Evaluation *****
#   Num examples = 234
#   Batch size = 48
#     <div>
#
#       <progress value='936' max='931' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [931/931 13:54]
#     </div>
# {'epoch': 10.0,
#  'eval_AUC_Atelectasis': 0.8227678571428573,
#  'eval_AUC_Cardiomegaly': 0.8189670446491849,
#  'eval_AUC_Consolidation': 0.9027589326096788,
#  'eval_AUC_Edema': 0.9233392122281011,
#  'eval_AUC_Pleural Effusion': 0.9306908570917867,
#  'eval_accuracy': 0.4658119658119658,
#  'eval_f1': 0.4759615384615385,
#  'eval_loss': 0.4080140292644501,
#  'eval_runtime': 2.4658,
#  'eval_samples_per_second': 94.896,
#  'eval_steps_per_second': 2.028}
