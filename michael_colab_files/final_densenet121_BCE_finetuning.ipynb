# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# # DenseNet121
#
# BCE Loss
#
# Hyperparameters taken from libauc multilabel example

# %%
# Mount into drive
from google.colab import drive
drive.mount("/content/drive")
# !cp '/content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/CheXpert-v1.0-small.zip' /content/
# !mkdir CheXpert
# !unzip '/content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/CheXpert-v1.0-small.zip' -d /content/CheXpert
import sys
sys.path.append('/content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/tyler')
sys.path.append('/content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation')
sys.path.append('/content/drive/MyDrive/Georgia Tech/CS 7643 Deep Learning/chestx_interpretation/models')

# %%
# imports
# !pip install transformers
# !pip install libauc
import numpy as np
import pandas as pd

# %load_ext autoreload
# %autoreload 2

import torch
print(torch.cuda.is_available())

from transformers import AutoFeatureExtractor, SwinForImageClassification, SwinConfig
from transformers import ConvNextFeatureExtractor, ConvNextForImageClassification
from transformers import TrainingArguments, Trainer
from torchvision.transforms import RandomHorizontalFlip, RandomResizedCrop
from torchvision.transforms.functional import InterpolationMode
import torchvision.models as models
from libauc.models import DenseNet121, DenseNet169

from sklearn.model_selection import train_test_split

# %%
from dataloader import *
from utils import *
from trainer import *

# %%
from libauc.losses import AUCM_MultiLabel, CrossEntropyLoss
from libauc.optimizers import PESG, Adam
from libauc.models import DenseNet121, DenseNet169
from libauc.datasets import CheXpert

import torch 
from PIL import Image
import numpy as np
import torchvision.transforms as transforms
from torch.utils.data import Dataset
from sklearn.metrics import roc_auc_score
import torch.nn.functional as F

# %%
def set_all_seeds(SEED):
    # REPRODUCIBILITY
    torch.manual_seed(SEED)
    np.random.seed(SEED)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
# dataloader
root = '/content/CheXpert/CheXpert-v1.0-small/'
# Index: -1 denotes multi-label mode including 5 diseases
traindSet = CheXpert(csv_path=root+'train.csv', image_root_path=root, use_upsampling=False, use_frontal=False, image_size=224, mode='train', class_index=-1, verbose=False)
testSet =  CheXpert(csv_path=root+'valid.csv',  image_root_path=root, use_upsampling=False, use_frontal=False, image_size=224, mode='valid', class_index=-1, verbose=False)
trainloader =  torch.utils.data.DataLoader(traindSet, batch_size=32, num_workers=2, shuffle=True)
testloader =  torch.utils.data.DataLoader(testSet, batch_size=32, num_workers=2, shuffle=False)

# paramaters
SEED = 123
BATCH_SIZE = 32
 
lr = 0.001 # using smaller learning rate is better
gamma = 500
imratio = traindSet.imratio_list 
weight_decay = 1e-5
margin = 1.0

# model
set_all_seeds(SEED)
model = DenseNet121(pretrained=True, last_activation=None, activations='relu', num_classes=5)
model = model.cuda()

# define loss & optimizer
Loss = CrossEntropyLoss()
# Loss = AUCM_MultiLabel(imratio=imratio, num_classes=5)
optimizer = Adam(model.parameters(),lr=lr, weight_decay=weight_decay)
# optimizer = PESG(model, 
#                  a=Loss.a, 
#                  b=Loss.b, 
#                  alpha=Loss.alpha, 
#                  lr=lr, 
#                  gamma=gamma, 
#                  margin=margin, 
#                  weight_decay=weight_decay, device='cuda')


# training
best_val_auc = 0 
for epoch in range(10):
    # if epoch > 0:
    #     optimizer.update_regularizer(decay_factor=10)       
    for idx, data in enumerate(trainloader):
      train_data, train_labels = data
      train_data, train_labels  = train_data.cuda(), train_labels.cuda()
      y_pred = model(train_data)
      # y_pred = torch.sigmoid(y_pred)
      loss = Loss(y_pred, train_labels)
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
        
      # validation  
      if idx % 400 == 0:
         model.eval()
         with torch.no_grad():    
              test_pred = []
              test_true = [] 
              for jdx, data in enumerate(testloader):
                  test_data, test_labels = data
                  test_data = test_data.cuda()
                  y_pred = model(test_data)
                  y_pred = torch.sigmoid(y_pred)
                  test_pred.append(y_pred.cpu().detach().numpy())
                  test_true.append(test_labels.numpy())
            
              test_true = np.concatenate(test_true)
              test_pred = np.concatenate(test_pred)
              val_auc_mean =  roc_auc_score(test_true, test_pred) 
              model.train()

              if best_val_auc < val_auc_mean:
                 best_val_auc = val_auc_mean
                 torch.save(model.state_dict(), 'aucm_multi_label_pretrained_model.pth')

              print ('Epoch=%s, BatchID=%s, Val_AUC=%.4f, Best_Val_AUC=%.4f'%(epoch, idx, val_auc_mean, best_val_auc))
# Out:
# /usr/local/lib/python3.7/dist-packages/libauc/datasets/chexpert.py:35: FutureWarning: The default value of regex will change from True to False in a future version.
#   self.df['Path'] = self.df['Path'].str.replace('CheXpert-v1.0-small/', '')
# /usr/local/lib/python3.7/dist-packages/libauc/datasets/chexpert.py:36: FutureWarning: The default value of regex will change from True to False in a future version.
#   self.df['Path'] = self.df['Path'].str.replace('CheXpert-v1.0/', '')
# Epoch=0, BatchID=0, Val_AUC=0.5576, Best_Val_AUC=0.5576
# Epoch=0, BatchID=400, Val_AUC=0.7694, Best_Val_AUC=0.7694
# Epoch=0, BatchID=800, Val_AUC=0.8514, Best_Val_AUC=0.8514
# Epoch=0, BatchID=1200, Val_AUC=0.8414, Best_Val_AUC=0.8514
# Epoch=0, BatchID=1600, Val_AUC=0.8605, Best_Val_AUC=0.8605
# Epoch=0, BatchID=2000, Val_AUC=0.8608, Best_Val_AUC=0.8608
# Epoch=0, BatchID=2400, Val_AUC=0.8418, Best_Val_AUC=0.8608
# Epoch=0, BatchID=2800, Val_AUC=0.8356, Best_Val_AUC=0.8608
# Epoch=0, BatchID=3200, Val_AUC=0.8489, Best_Val_AUC=0.8608
# Epoch=0, BatchID=3600, Val_AUC=0.8684, Best_Val_AUC=0.8684
# Epoch=0, BatchID=4000, Val_AUC=0.8500, Best_Val_AUC=0.8684
# Epoch=0, BatchID=4400, Val_AUC=0.8612, Best_Val_AUC=0.8684
# Epoch=0, BatchID=4800, Val_AUC=0.8410, Best_Val_AUC=0.8684
# Epoch=0, BatchID=5200, Val_AUC=0.8440, Best_Val_AUC=0.8684
# Epoch=0, BatchID=5600, Val_AUC=0.7928, Best_Val_AUC=0.8684
# Epoch=0, BatchID=6000, Val_AUC=0.8622, Best_Val_AUC=0.8684
# Epoch=0, BatchID=6400, Val_AUC=0.8775, Best_Val_AUC=0.8775
# Epoch=0, BatchID=6800, Val_AUC=0.8618, Best_Val_AUC=0.8775
# Epoch=1, BatchID=0, Val_AUC=0.8658, Best_Val_AUC=0.8775
# Epoch=1, BatchID=400, Val_AUC=0.8331, Best_Val_AUC=0.8775
# Epoch=1, BatchID=800, Val_AUC=0.8689, Best_Val_AUC=0.8775
# Epoch=1, BatchID=1200, Val_AUC=0.8299, Best_Val_AUC=0.8775
# Epoch=1, BatchID=1600, Val_AUC=0.8238, Best_Val_AUC=0.8775
# Epoch=1, BatchID=2000, Val_AUC=0.8663, Best_Val_AUC=0.8775
# Epoch=1, BatchID=2400, Val_AUC=0.8525, Best_Val_AUC=0.8775
# Epoch=1, BatchID=2800, Val_AUC=0.8320, Best_Val_AUC=0.8775
# Epoch=1, BatchID=3200, Val_AUC=0.8599, Best_Val_AUC=0.8775
# Epoch=1, BatchID=3600, Val_AUC=0.8523, Best_Val_AUC=0.8775
# Epoch=1, BatchID=4000, Val_AUC=0.8693, Best_Val_AUC=0.8775
# Epoch=1, BatchID=4400, Val_AUC=0.8516, Best_Val_AUC=0.8775
# Epoch=1, BatchID=4800, Val_AUC=0.8665, Best_Val_AUC=0.8775
# Epoch=1, BatchID=5200, Val_AUC=0.8670, Best_Val_AUC=0.8775
# Epoch=1, BatchID=5600, Val_AUC=0.8621, Best_Val_AUC=0.8775
# Epoch=1, BatchID=6000, Val_AUC=0.8315, Best_Val_AUC=0.8775
# Epoch=1, BatchID=6400, Val_AUC=0.8698, Best_Val_AUC=0.8775
# Epoch=1, BatchID=6800, Val_AUC=0.8544, Best_Val_AUC=0.8775
# Epoch=2, BatchID=0, Val_AUC=0.8631, Best_Val_AUC=0.8775
# Epoch=2, BatchID=400, Val_AUC=0.8705, Best_Val_AUC=0.8775
# Epoch=2, BatchID=800, Val_AUC=0.8375, Best_Val_AUC=0.8775
# Epoch=2, BatchID=1200, Val_AUC=0.8659, Best_Val_AUC=0.8775
# Epoch=2, BatchID=1600, Val_AUC=0.8486, Best_Val_AUC=0.8775
# Epoch=2, BatchID=2000, Val_AUC=0.8476, Best_Val_AUC=0.8775
# Epoch=2, BatchID=2400, Val_AUC=0.8591, Best_Val_AUC=0.8775
# Epoch=2, BatchID=2800, Val_AUC=0.8585, Best_Val_AUC=0.8775
# Epoch=2, BatchID=3200, Val_AUC=0.8580, Best_Val_AUC=0.8775
# Epoch=2, BatchID=3600, Val_AUC=0.8735, Best_Val_AUC=0.8775
# Epoch=2, BatchID=4000, Val_AUC=0.8825, Best_Val_AUC=0.8825
# Epoch=2, BatchID=4400, Val_AUC=0.8643, Best_Val_AUC=0.8825
# Epoch=2, BatchID=4800, Val_AUC=0.8436, Best_Val_AUC=0.8825
# Epoch=2, BatchID=5200, Val_AUC=0.8860, Best_Val_AUC=0.8860
# Epoch=2, BatchID=5600, Val_AUC=0.8833, Best_Val_AUC=0.8860
# Epoch=2, BatchID=6000, Val_AUC=0.8787, Best_Val_AUC=0.8860
# Epoch=2, BatchID=6400, Val_AUC=0.8637, Best_Val_AUC=0.8860
# Epoch=2, BatchID=6800, Val_AUC=0.8833, Best_Val_AUC=0.8860
# Epoch=3, BatchID=0, Val_AUC=0.8787, Best_Val_AUC=0.8860
# Epoch=3, BatchID=400, Val_AUC=0.8690, Best_Val_AUC=0.8860
# Epoch=3, BatchID=800, Val_AUC=0.8580, Best_Val_AUC=0.8860
# Epoch=3, BatchID=1200, Val_AUC=0.8838, Best_Val_AUC=0.8860
# Epoch=3, BatchID=1600, Val_AUC=0.8274, Best_Val_AUC=0.8860
# Epoch=3, BatchID=2000, Val_AUC=0.8832, Best_Val_AUC=0.8860
# Epoch=3, BatchID=2400, Val_AUC=0.8431, Best_Val_AUC=0.8860
# Epoch=3, BatchID=2800, Val_AUC=0.8766, Best_Val_AUC=0.8860
# Epoch=3, BatchID=3200, Val_AUC=0.8859, Best_Val_AUC=0.8860
# Epoch=3, BatchID=3600, Val_AUC=0.8767, Best_Val_AUC=0.8860
# Epoch=3, BatchID=4000, Val_AUC=0.8659, Best_Val_AUC=0.8860
# Epoch=3, BatchID=4400, Val_AUC=0.8572, Best_Val_AUC=0.8860
# Epoch=3, BatchID=4800, Val_AUC=0.8709, Best_Val_AUC=0.8860
# Epoch=3, BatchID=5200, Val_AUC=0.8564, Best_Val_AUC=0.8860
# Epoch=3, BatchID=5600, Val_AUC=0.8549, Best_Val_AUC=0.8860
# Epoch=3, BatchID=6000, Val_AUC=0.8647, Best_Val_AUC=0.8860
# Epoch=3, BatchID=6400, Val_AUC=0.8727, Best_Val_AUC=0.8860
# Epoch=3, BatchID=6800, Val_AUC=0.8652, Best_Val_AUC=0.8860
# Epoch=4, BatchID=0, Val_AUC=0.8759, Best_Val_AUC=0.8860
# Epoch=4, BatchID=400, Val_AUC=0.8715, Best_Val_AUC=0.8860
# Epoch=4, BatchID=800, Val_AUC=0.8641, Best_Val_AUC=0.8860
# Epoch=4, BatchID=1200, Val_AUC=0.8748, Best_Val_AUC=0.8860
# Epoch=4, BatchID=1600, Val_AUC=0.8557, Best_Val_AUC=0.8860
# Epoch=4, BatchID=2000, Val_AUC=0.8740, Best_Val_AUC=0.8860
# Epoch=4, BatchID=2400, Val_AUC=0.8734, Best_Val_AUC=0.8860
# Epoch=4, BatchID=2800, Val_AUC=0.8741, Best_Val_AUC=0.8860
# Epoch=4, BatchID=3200, Val_AUC=0.8752, Best_Val_AUC=0.8860
# Epoch=4, BatchID=3600, Val_AUC=0.8680, Best_Val_AUC=0.8860
# Epoch=4, BatchID=4000, Val_AUC=0.8745, Best_Val_AUC=0.8860
# Epoch=4, BatchID=4400, Val_AUC=0.8863, Best_Val_AUC=0.8863
# Epoch=4, BatchID=4800, Val_AUC=0.8404, Best_Val_AUC=0.8863
# Epoch=4, BatchID=5200, Val_AUC=0.8726, Best_Val_AUC=0.8863
# Epoch=4, BatchID=5600, Val_AUC=0.8523, Best_Val_AUC=0.8863
# Epoch=4, BatchID=6000, Val_AUC=0.8750, Best_Val_AUC=0.8863
# Epoch=4, BatchID=6400, Val_AUC=0.8721, Best_Val_AUC=0.8863
# Epoch=4, BatchID=6800, Val_AUC=0.8620, Best_Val_AUC=0.8863
# Epoch=5, BatchID=0, Val_AUC=0.8920, Best_Val_AUC=0.8920
# Epoch=5, BatchID=400, Val_AUC=0.8732, Best_Val_AUC=0.8920
# Epoch=5, BatchID=800, Val_AUC=0.8771, Best_Val_AUC=0.8920
# Epoch=5, BatchID=1200, Val_AUC=0.8889, Best_Val_AUC=0.8920
# Epoch=5, BatchID=1600, Val_AUC=0.8689, Best_Val_AUC=0.8920
# Epoch=5, BatchID=2000, Val_AUC=0.8702, Best_Val_AUC=0.8920
# Epoch=5, BatchID=2400, Val_AUC=0.8841, Best_Val_AUC=0.8920
# Epoch=5, BatchID=2800, Val_AUC=0.8824, Best_Val_AUC=0.8920
# Epoch=5, BatchID=3200, Val_AUC=0.8883, Best_Val_AUC=0.8920
# Epoch=5, BatchID=3600, Val_AUC=0.8743, Best_Val_AUC=0.8920
# Epoch=5, BatchID=4000, Val_AUC=0.8420, Best_Val_AUC=0.8920
# Epoch=5, BatchID=4400, Val_AUC=0.8620, Best_Val_AUC=0.8920
# Epoch=5, BatchID=4800, Val_AUC=0.8753, Best_Val_AUC=0.8920
# Epoch=5, BatchID=5200, Val_AUC=0.8734, Best_Val_AUC=0.8920
# Epoch=5, BatchID=5600, Val_AUC=0.8649, Best_Val_AUC=0.8920
# Epoch=5, BatchID=6000, Val_AUC=0.8438, Best_Val_AUC=0.8920
# Epoch=5, BatchID=6400, Val_AUC=0.8210, Best_Val_AUC=0.8920
# Epoch=5, BatchID=6800, Val_AUC=0.8585, Best_Val_AUC=0.8920
# Epoch=6, BatchID=0, Val_AUC=0.8858, Best_Val_AUC=0.8920
# Epoch=6, BatchID=400, Val_AUC=0.8577, Best_Val_AUC=0.8920
# Epoch=6, BatchID=800, Val_AUC=0.8178, Best_Val_AUC=0.8920
# Epoch=6, BatchID=1200, Val_AUC=0.8351, Best_Val_AUC=0.8920
# Epoch=6, BatchID=1600, Val_AUC=0.8417, Best_Val_AUC=0.8920
# Epoch=6, BatchID=2000, Val_AUC=0.8716, Best_Val_AUC=0.8920
# Epoch=6, BatchID=2400, Val_AUC=0.8748, Best_Val_AUC=0.8920
# Epoch=6, BatchID=2800, Val_AUC=0.8709, Best_Val_AUC=0.8920
# Epoch=6, BatchID=3200, Val_AUC=0.8546, Best_Val_AUC=0.8920
# Epoch=6, BatchID=3600, Val_AUC=0.8705, Best_Val_AUC=0.8920
# Epoch=6, BatchID=4000, Val_AUC=0.8497, Best_Val_AUC=0.8920
# Epoch=6, BatchID=4400, Val_AUC=0.8646, Best_Val_AUC=0.8920
# Epoch=6, BatchID=4800, Val_AUC=0.8633, Best_Val_AUC=0.8920
# Epoch=6, BatchID=5200, Val_AUC=0.8831, Best_Val_AUC=0.8920
# Epoch=6, BatchID=5600, Val_AUC=0.8437, Best_Val_AUC=0.8920
# Epoch=6, BatchID=6000, Val_AUC=0.8187, Best_Val_AUC=0.8920
# Epoch=6, BatchID=6400, Val_AUC=0.8918, Best_Val_AUC=0.8920
# Epoch=6, BatchID=6800, Val_AUC=0.8736, Best_Val_AUC=0.8920
# Epoch=7, BatchID=0, Val_AUC=0.8437, Best_Val_AUC=0.8920
# Epoch=7, BatchID=400, Val_AUC=0.8680, Best_Val_AUC=0.8920
# Epoch=7, BatchID=800, Val_AUC=0.8310, Best_Val_AUC=0.8920
# Epoch=7, BatchID=1200, Val_AUC=0.8526, Best_Val_AUC=0.8920
# Epoch=7, BatchID=1600, Val_AUC=0.8779, Best_Val_AUC=0.8920
# Epoch=7, BatchID=2000, Val_AUC=0.8758, Best_Val_AUC=0.8920
# Epoch=7, BatchID=2400, Val_AUC=0.8547, Best_Val_AUC=0.8920
# Epoch=7, BatchID=2800, Val_AUC=0.8737, Best_Val_AUC=0.8920
# Epoch=7, BatchID=3200, Val_AUC=0.8885, Best_Val_AUC=0.8920
# Epoch=7, BatchID=3600, Val_AUC=0.8757, Best_Val_AUC=0.8920
# Epoch=7, BatchID=4000, Val_AUC=0.8417, Best_Val_AUC=0.8920
# Epoch=7, BatchID=4400, Val_AUC=0.8680, Best_Val_AUC=0.8920
# Epoch=7, BatchID=4800, Val_AUC=0.8790, Best_Val_AUC=0.8920
# Epoch=7, BatchID=5200, Val_AUC=0.8569, Best_Val_AUC=0.8920
# Epoch=7, BatchID=5600, Val_AUC=0.8829, Best_Val_AUC=0.8920
# Epoch=7, BatchID=6000, Val_AUC=0.8773, Best_Val_AUC=0.8920
# Epoch=7, BatchID=6400, Val_AUC=0.8620, Best_Val_AUC=0.8920
# Epoch=7, BatchID=6800, Val_AUC=0.8740, Best_Val_AUC=0.8920
# Epoch=8, BatchID=0, Val_AUC=0.8645, Best_Val_AUC=0.8920
# Epoch=8, BatchID=400, Val_AUC=0.8747, Best_Val_AUC=0.8920
# Epoch=8, BatchID=800, Val_AUC=0.8836, Best_Val_AUC=0.8920
# Epoch=8, BatchID=1200, Val_AUC=0.8865, Best_Val_AUC=0.8920
# Epoch=8, BatchID=1600, Val_AUC=0.8697, Best_Val_AUC=0.8920
# Epoch=8, BatchID=2000, Val_AUC=0.8856, Best_Val_AUC=0.8920
# Epoch=8, BatchID=2400, Val_AUC=0.8786, Best_Val_AUC=0.8920
# Epoch=8, BatchID=2800, Val_AUC=0.8911, Best_Val_AUC=0.8920
# Epoch=8, BatchID=3200, Val_AUC=0.8711, Best_Val_AUC=0.8920
# Epoch=8, BatchID=3600, Val_AUC=0.8508, Best_Val_AUC=0.8920
# Epoch=8, BatchID=4000, Val_AUC=0.8745, Best_Val_AUC=0.8920
# Epoch=8, BatchID=4400, Val_AUC=0.8915, Best_Val_AUC=0.8920
# Epoch=8, BatchID=4800, Val_AUC=0.8633, Best_Val_AUC=0.8920
# Epoch=8, BatchID=5200, Val_AUC=0.8785, Best_Val_AUC=0.8920
# Epoch=8, BatchID=5600, Val_AUC=0.8250, Best_Val_AUC=0.8920
# Epoch=8, BatchID=6000, Val_AUC=0.8787, Best_Val_AUC=0.8920
# Epoch=8, BatchID=6400, Val_AUC=0.8167, Best_Val_AUC=0.8920
# Epoch=8, BatchID=6800, Val_AUC=0.8618, Best_Val_AUC=0.8920
# Epoch=9, BatchID=0, Val_AUC=0.8945, Best_Val_AUC=0.8945
# Epoch=9, BatchID=400, Val_AUC=0.8657, Best_Val_AUC=0.8945
# Epoch=9, BatchID=800, Val_AUC=0.8609, Best_Val_AUC=0.8945
# Epoch=9, BatchID=1200, Val_AUC=0.8332, Best_Val_AUC=0.8945
# Epoch=9, BatchID=1600, Val_AUC=0.8996, Best_Val_AUC=0.8996
# Epoch=9, BatchID=2000, Val_AUC=0.8803, Best_Val_AUC=0.8996
# Epoch=9, BatchID=2400, Val_AUC=0.8711, Best_Val_AUC=0.8996
# Epoch=9, BatchID=2800, Val_AUC=0.8499, Best_Val_AUC=0.8996
# Epoch=9, BatchID=3200, Val_AUC=0.8887, Best_Val_AUC=0.8996
# Epoch=9, BatchID=3600, Val_AUC=0.8837, Best_Val_AUC=0.8996
# Epoch=9, BatchID=4000, Val_AUC=0.8453, Best_Val_AUC=0.8996
# Epoch=9, BatchID=4400, Val_AUC=0.8740, Best_Val_AUC=0.8996
# Epoch=9, BatchID=4800, Val_AUC=0.8560, Best_Val_AUC=0.8996
# Epoch=9, BatchID=5200, Val_AUC=0.8758, Best_Val_AUC=0.8996
# Epoch=9, BatchID=5600, Val_AUC=0.8514, Best_Val_AUC=0.8996
# Epoch=9, BatchID=6000, Val_AUC=0.8502, Best_Val_AUC=0.8996
