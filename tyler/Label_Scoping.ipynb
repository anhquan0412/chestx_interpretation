# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from utils import *
from dataloader import COMPETITION_TASKS

# %%
np.random.seed(42)
train_df = pd.read_csv("ChexPert/train.csv")
train_df, eval_df = train_test_split(train_df, train_size=0.8)

# %%
train_df["Frontal/Lateral"].value_counts()
# Out:
# Frontal    152878
# Lateral     25853
# Name: Frontal/Lateral, dtype: int64

# %%
train_df["No Finding"].fillna(0).mean()
# Out:
# 0.10007217550396966

# %%
train_df[COMPETITION_TASKS].fillna(0).replace(-1, 0).mean(axis=0).tolist()
# Out:
# [0.1497333982353369,
#  0.12095831165270714,
#  0.0663119436471569,
#  0.2344081328924473,
#  0.3860606162333339]

# %%
train_df[np.abs(train_df[COMPETITION_TASKS].sum(axis=1)) == 2]
# Out:
#                                                      Path     Sex  Age  \
# 164722  CheXpert-v1.0-small/train/patient38415/study3/...    Male   77
# 165162  CheXpert-v1.0-small/train/patient38526/study8/...    Male   69
# 70759   CheXpert-v1.0-small/train/patient16972/study1/...    Male   71
# 175740  CheXpert-v1.0-small/train/patient41125/study5/...    Male   66
# 106830  CheXpert-v1.0-small/train/patient25662/study4/...  Female   90
# ...                                                   ...     ...  ...
# 199041  CheXpert-v1.0-small/train/patient49155/study4/...  Female   84
# 64925   CheXpert-v1.0-small/train/patient15625/study2/...    Male   45
# 54886   CheXpert-v1.0-small/train/patient13309/study16...  Female   47
# 119879  CheXpert-v1.0-small/train/patient28725/study2/...  Female   56
# 146867  CheXpert-v1.0-small/train/patient35028/study1/...    Male   69
#
#        Frontal/Lateral AP/PA  No Finding  Enlarged Cardiomediastinum  \
# ...

# %%
validation_df = pd.read_csv("ChexPert/valid.csv")

# %%
(validation_df[COMPETITION_TASKS] == -1).sum()
# Out:
# No Finding          0
# Atelectasis         0
# Cardiomegaly        0
# Consolidation       0
# Edema               0
# Pleural Effusion    0
# dtype: int64
